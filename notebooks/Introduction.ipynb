# %% [markdown]
# # Introduction
# ---
#
# Throughout this course we will be using *R for Data Science* book by Hadley Wickham and Garrett Grolemund. Many of the concept definitions, examples, and images in these notebook series are directly taken from Hadley's book, typically with some modifications. For a deeper understanding I recommend reading his book. You can get access to the electronic copy for free [here](http://r4ds.had.co.nz/). Please note that the order of the materials does not necessarily coincide with the notebooks.
#
# A typical workflow in a data science project looks something like this:
#
# <img src="../png/data-science.png" width="600px" align="center">
#
# We will touch on all of these modules separately in the upcoming notebooks and work with some of the most popular tools to answer questions about our data. You'll use these tools in every data science project, but for most projects they're not enough. There's a rough 80-20 rule at play; you can tackle about 80% of every project using the tools that you'll learn here, but you'll need other tools to tackle the remaining 20% which could vary based on the problem.

# %% [markdown]
# ---
#
# ## How are the notebooks organized?
# The notebooks are organized roughly in the same order as you would use them in a typical data science project. You can use the following guide to navigate your way to the right notebook:
#
# ### R Bootcamp - Notebooks Map
#
# **00 Introduction**
#
# **01 Setup**
# * Textbook and credits
# * Downloading course material
# * Installations
# * Binder
# * Jupyter
#
# **02 Data-Visualization**
# * Overview of `ggplot2`
# * Scatter plots
# * Histograms
# * Bar plots
# * Box plots
# * Facets
# * Themes
#
# **03 Coding Basics**
# * Vectors
# * Matrices
# * Lists
# * Data frames
# * Tibbles
# * Conditional statements
# * Loops
# * Functions
#
# **04 Workflow**
# * Scripts
# * Projects
#
# **05 Data Transformation**
# * Overview of `dplyr`
# * Filter rows with `filter()`
# * Arrange rows with `arrange()`
# * Select columns with `select()`
# * Add new variables with `mutate()`
# * Grouped summaries with `summarise()`
#
# **06 Exploratory Data Analysis**
#
# **07 Data Import and Export with `readr`**
#
# **08 Data manipulation**
# * Tidy data with `tidyr`
# * Relational Data with `dplyr`
# * Strings with `stringr`
# * Factors with `forcats`
# * Dates and Time with `lubridate`
# * Pipes with `magrittr`
#
# **09 Functions**
#
# **10 Introduction to Machine Learning**
#
# **11 Model Building with `modelr`**
# * Linear regression
# * Logistic regression
# * K nearest neighbor
# * Decision trees
# * Support vector machines
# * K-means clustering
# * Neural networks
#
# **12 R Markdown**
#
# **13 Interactive Visualization with `plotly`**
#
# Additional topics:
#
# * **Iteration with `purrr`**
